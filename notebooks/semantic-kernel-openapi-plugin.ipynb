# %%
# Install required packages (if not already installed)
# %pip install prance openai semantic-kernel nest_asyncio asyncio python-dotenv requests azure-identity azure-mgmt-resource -U
# Out:
# Requirement already satisfied: prance in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (23.6.21.0)
# Requirement already satisfied: openai in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (1.58.1)
# Requirement already satisfied: semantic-kernel in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (1.17.0)
# Requirement already satisfied: nest_asyncio in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (1.6.0)
# Requirement already satisfied: asyncio in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (3.4.3)
# Requirement already satisfied: python-dotenv in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: requests in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (2.32.3)
# Requirement already satisfied: azure-identity in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (1.19.0)
# Requirement already satisfied: azure-mgmt-resource in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (23.2.0)
# Requirement already satisfied: chardet>=3.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from prance) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from prance) (0.18.6)
# Requirement already satisfied: six~=1.15 in c:\users\adhocke\appdata\roaming\python\python312\site-packages (from prance) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\adhocke\appdata\roaming\python\python312\site-packages (from prance) (23.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: aiohttp~=3.8 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (3.11.10)
# Requirement already satisfied: cloudevents~=1.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (1.11.0)
# Requirement already satisfied: pydantic-settings~=2.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (2.7.0)
# Requirement already satisfied: defusedxml~=0.7 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (2.1.3)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (0.19.4)
# Requirement already satisfied: opentelemetry-api~=1.24 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (1.29.0)
# Requirement already satisfied: pybars4~=0.9 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from semantic-kernel) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from azure-identity) (1.32.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from azure-identity) (43.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from azure-identity) (1.31.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from azure-mgmt-resource) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from azure-mgmt-resource) (1.1.28)
# Requirement already satisfied: azure-mgmt-core>=1.3.2 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from azure-mgmt-resource) (1.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.18.3)
# Requirement already satisfied: deprecation<3.0,>=2.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from cloudevents~=1.0->semantic-kernel) (2.1.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: httpcore==1.* in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from jinja2~=3.1->semantic-kernel) (3.0.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.3)
# Requirement already satisfied: more-itertools in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.5.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.2)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.1)
# Requirement already satisfied: parse in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (3.1.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.5.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.50b0)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from ruamel.yaml>=0.17.10->prance) (0.2.12)
# Requirement already satisfied: colorama in c:\users\adhocke\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.21.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.3)
# Requirement already satisfied: rfc3339-validator in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\adhocke\appdata\local\programs\python\python312\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.10.0)
# Requirement already satisfied: pywin32>=226 in c:\users\adhocke\appdata\roaming\python\python312\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity) (306)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import os
import asyncio
import logging
import requests
import tempfile
import re

from azure.identity import DefaultAzureCredential

from functools import reduce
from dotenv import load_dotenv, find_dotenv
from prance import ResolvingParser
from prance.util import resolver
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.function_choice_behavior import FunctionChoiceBehavior
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.contents.chat_history import ChatHistory
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.kernel import Kernel
from semantic_kernel.connectors.openapi_plugin.openapi_parser import OpenApiParser
from semantic_kernel.connectors.openapi_plugin.openapi_function_execution_parameters import (
        OpenAPIFunctionExecutionParameters,
    )

# Load environment variables from .env.local if it exists, otherwise fallback to .env
load_dotenv('.env.local')
load_dotenv()
# Out:
# False

# %%
# To toggle streaming or non-streaming mode, change the following boolean
streaming = True

# Define the agent name and instructions
AGENT_ID = "agent1"
AGENT_NAME = "agent1"
AGENT_INSTRUCTIONS = (
                "Instructions:\n"
                " - Break the task into steps, and output the result of each step as you perform it.\n"
                " - You are an AI assistant that helps with calling APIs to generate useful information based on a user's question.\n"
                " - Use the proper function calls to get information that will be useful to the user.\n"
                " - If one function call depends on the output of another, make sure to call them in order and use the outputs appropriately.\n"
                " - Include what you are thinking, working on, and next steps in your responses, and ask for more information if needed.\n"
                " - If you don't know something, and are not able to ask the user for more information, or can't call an API, you can say 'I don't know'.\n"
                " - Always format an email as HTML. Ensure the content is well orangized and use bullet lists or tables where necessary.\n"
                " - For Weather API's, if a query parameter is required, read the description as the query will need to be converted into latitude and longitude and not a city and state.\n"
            )

subscription_id = os.environ["AZURE_SUBSCRIPTION_ID"]
resource_group = os.environ["AZURE_RESOURCE_GROUP"]
service_name = os.environ["AZURE_APIM_SERVICE_NAME"]
api_version = os.environ["AZURE_APIM_SERVICE_API_VERSION"]
product_id = os.environ["AZURE_APIM_SERVICE_PRODUCT_ID"]
subscription_key = os.environ["AZURE_APIM_SERVICE_SUBSCRIPTION_KEY"]

# %%
async def invoke_agent(agent: ChatCompletionAgent, input: str, chat: ChatHistory):
    """Invoke the agent with the user input."""
    chat.add_user_message(input)

    print(f"# {AuthorRole.USER}: '{input}'")

    if streaming:
        contents = []
        content_name = ""
        async for content in agent.invoke_stream(chat):
            content_name = content.name
            contents.append(content)
        streaming_chat_message = reduce(lambda first, second: first + second, contents)
        print(f"# {content.role} - {content_name or '*'}: '{streaming_chat_message}'")
        chat.add_message(streaming_chat_message)
    else:
        async for content in agent.invoke(chat):
            print(f"# {content.role} - {content.name or '*'}: '{content.content}'")
            chat.add_message(content)

# %%
def sanitize_plugin_name(name):
    # Replace any character that is not a letter, number, or underscore with an underscore
    sanitized_name = re.sub(r'[^0-9A-Za-z_]', '_', name)
    # Remove leading underscores or numbers to ensure valid identifier if necessary
    sanitized_name = re.sub(r'^[^A-Za-z]+', '', sanitized_name)
    # Ensure the name is not empty
    if not sanitized_name:
        sanitized_name = 'plugin'
    return sanitized_name

# %%
async def add_openapi_plugin(kernel: Kernel, plugin_name:str, openapi_spec: str):

    print(f"    > Adding OpenAPI plugin '{plugin_name}'")
    
    parser = ResolvingParser(spec_string=openapi_spec, resolve_types = resolver.RESOLVE_FILES, strict=False, recursion_limit=10)
    parsed_spec = parser.specification

    async def my_auth_callback(**kwargs):
        return {"Ocp-Apim-Subscription-Key": os.environ["AZURE_APIM_SERVICE_SUBSCRIPTION_KEY"], "Content-Type": "application/json"}

    kernel.add_plugin_from_openapi(
        plugin_name=plugin_name,
        openapi_parsed_spec=parsed_spec,
        execution_settings=OpenAPIFunctionExecutionParameters(
                # Determines whether payload parameter names are augmented with namespaces.
                # Namespaces prevent naming conflicts by adding the parent parameter name
                # as a prefix, separated by dots
                auth_callback=my_auth_callback,
                enable_payload_namespacing=True
        )
    )

# %%
# Authenticate and get an access token
def get_access_token():
    credential = DefaultAzureCredential()
    token = credential.get_token("https://management.azure.com/.default")
    return token.token

# %%
# Function to fetch APIs that belong to a certain product
def fetch_apis_by_product(access_token, product_id):
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json'
    }
    url = f'https://management.azure.com/subscriptions/{subscription_id}/resourceGroups/{resource_group}/providers/Microsoft.ApiManagement/service/{service_name}/products/{product_id}/apis?api-version={api_version}'
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()['value']

# Get the OpenAPI JSON file from the export endpoint
def fetch_openapi_spec(api_id, access_token):
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json'
    }
    url = f'https://management.azure.com/subscriptions/{subscription_id}/resourceGroups/{resource_group}/providers/Microsoft.ApiManagement/service/{service_name}/apis/{api_id}?export=true&format=openapi&api-version={api_version}'
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    #return response.json()
    return response.text

# %%
async def add_apim_apis_by_product(kernel, product_id):

    # Get the access token  
    access_token = get_access_token()

    # Fetch the APIs that belong to the specified product
    apis = fetch_apis_by_product(access_token, product_id)

    # Add the OpenAPI plugins for each API
    plugin_names = set()
    for api in apis:
        openapi_spec = fetch_openapi_spec(api['name'], access_token)
        # Sanitize the plugin_name
        name_candidate = sanitize_plugin_name(api['name'])
        # Ensure the plugin_name is unique
        plugin_name = name_candidate
        counter = 1
        while plugin_name in plugin_names:
            plugin_name = f"{name_candidate}_{counter}"
            counter += 1
        plugin_names.add(plugin_name)
        await add_openapi_plugin(kernel, plugin_name, openapi_spec)

# %%
async def main():
    # Initialize the kernel
    kernel = Kernel()

    # Add Azure OpenAI chat completion
    chat_completion = AzureChatCompletion(
        deployment_name= os.environ["AZURE_OPENAI_MODEL"],
        api_key= os.environ["AZURE_OPENAI_KEY"],
        endpoint= os.environ["AZURE_OPENAI_ENDPOINT"],
        service_id=AGENT_ID
    )

    kernel.add_service(chat_completion)
    
    # Add the APIs from the specified product       
    await add_apim_apis_by_product(kernel, product_id)

    # Get the AI Service settings for the specified service_id
    settings = kernel.get_prompt_execution_settings_from_service_id(service_id=AGENT_ID)

    # Configure the function choice behavior to auto invoke kernel functions
    settings.function_choice_behavior = FunctionChoiceBehavior.Auto()

    # NOTE: This is all that is required to enable logging
    logging.basicConfig(level=logging.DEBUG)
    
    # Create the agent
    agent = ChatCompletionAgent(service_id=AGENT_ID, kernel=kernel, name=AGENT_NAME, instructions=AGENT_INSTRUCTIONS, execution_settings=settings)

    # Define the chat history
    chat = ChatHistory()

    # Respond to user input
    await invoke_agent(agent, "What is the weather in Orlando, FL? What product's would work for me with the current temperature? Once you have it, send an email to adam.hockemeyer@microsoft.com with the details.", chat)


# Run the main function
if __name__ == "__main__":
    await main()
# Out:
#     > Adding OpenAPI plugin 'azure_maps_weather_service'
#     > Adding OpenAPI plugin 'email_api'
#     > Adding OpenAPI plugin 'products_api'
# # AuthorRole.USER: 'What is the weather in Orlando, FL? What product's would work for me with the current temperature? Once you have it, send an email to adam.hockemeyer@microsoft.com with the details.'
# # AuthorRole.ASSISTANT - agent1: 'I have gathered the weather information for Orlando, FL and the recommended products based on the current temperature. I have also sent an email with the details to adam.hockemeyer@microsoft.com. Here is a summary:
#
# ### Weather in Orlando, FL
# - **Condition:** Sunny
# - **Temperature:** 25.5°C
# - **Real Feel Temperature:** 28.0°C
# - **Humidity:** 67%
# - **Wind:** 5.2 km/h NNW
# - **UV Index:** 2 (Low)
#
# ### Product Recommendations
# 1. **Winter Hiking Boots**
#    - Description: Durable boots suitable for winter hiking.
#    - Size: 10
#    - Color: Brown
#
# 2. **Thermal Jacket**
#    - Description: Insulated jacket ideal for cold weather.
#    - Size: L
#    - Color: Black
#
# 3. **Winter Gloves**
#    - Description: Warm gloves for cold climates.
#    - Size: M
#    - Color: Gray
#
# 4. **Thermal Socks**
#    - Description: Heat-retaining socks for cold temperatures.
#    - Size: One Size
#    - Color: Black
#
# The email has been successfully sent!'
